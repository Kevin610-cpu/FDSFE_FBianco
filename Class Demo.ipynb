# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevin610-cpu/FDSFE_FBianco/blob/main/Class%20Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pylab as plt

# %%
student_performance = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/refs/heads/main/StudentPerformanceFactors_modified.csv")
student_performance
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0              23.0        84.0                  Low                High
# 1              19.0        64.0                  Low              Medium
# 2              24.0        98.0               Medium              Medium
# 3              29.0        89.0                  Low              Medium
# 4               NaN        92.0               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602           25.0        69.0                 High              Medium
# 6603           23.0        76.0                 High              Medium
# 6604            NaN        90.0               Medium                 Low
# 6605           10.0        86.0                 High                High
# 6606           15.0        67.0               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
student_performance.shape
# Out:
# (6607, 20)

# %%
student_performance.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6527.000000  6521.000000  6526.000000      6528.000000
# mean       19.984832    79.990799     7.028042        75.067096
# std         5.993324    11.546369     1.469583        14.397116
# min         1.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        88.000000
# max        44.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6523.000000        6518.000000  6525.000000
# mean            1.493791           2.966247    67.240307
# std             1.231580           1.031094     3.882296
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6527 non-null   float64
#  1   Attendance                  6521 non-null   float64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6526 non-null   float64
#  6   Previous_Scores             6528 non-null   float64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6523 non-null   float64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
numerical_colNames=["Hours_Studied", "Attendance", "Sleep_Hours", "Previous_Scores", "Tutoring_Sessions", "Physical_Activity", "Exam_Score"]  # Remove the extra brackets
numerical_col= student_performance[numerical_colNames] # Remove extra brackets
numerical_col
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0              23.0        84.0          7.0             73.0
# 1              19.0        64.0          8.0             59.0
# 2              24.0        98.0          7.0             91.0
# 3              29.0        89.0          8.0             98.0
# 4               NaN        92.0          6.0             65.0
# ...             ...         ...          ...              ...
# 6602           25.0        69.0          7.0             76.0
# 6603           23.0        76.0          8.0             81.0
# 6604            NaN        90.0          6.0             65.0
# 6605           10.0        86.0          6.0             91.0
# 6606           15.0        67.0          9.0             94.0
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                   0.0                3.0        67.0
# 1                   2.0                4.0        61.0
# ...

# %%
numerical_col
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0              23.0        84.0          7.0             73.0
# 1              19.0        64.0          8.0             59.0
# 2              24.0        98.0          7.0             91.0
# 3              29.0        89.0          8.0             98.0
# 4               NaN        92.0          6.0             65.0
# ...             ...         ...          ...              ...
# 6602           25.0        69.0          7.0             76.0
# 6603           23.0        76.0          8.0             81.0
# 6604            NaN        90.0          6.0             65.0
# 6605           10.0        86.0          6.0             91.0
# 6606           15.0        67.0          9.0             94.0
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                   0.0                3.0        67.0
# 1                   2.0                4.0        61.0
# ...

# %%
student_performance.tail(10)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6597           16.0        91.0                 High              Medium
# 6598            9.0        87.0                  Low              Medium
# 6599           30.0        94.0               Medium                 Low
# 6600           12.0        98.0               Medium                 Low
# 6601            NaN        83.0               Medium                 Low
# 6602           25.0        69.0                 High              Medium
# 6603           23.0        76.0                 High              Medium
# 6604            NaN        90.0               Medium                 Low
# 6605           10.0        86.0                 High                High
# 6606           15.0        67.0               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6597                        Yes          6.0             72.0
# ...

# %%
student_performance.head(10)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0           23.0        84.0                  Low                High
# 1           19.0        64.0                  Low              Medium
# 2           24.0        98.0               Medium              Medium
# 3           29.0        89.0                  Low              Medium
# 4            NaN        92.0               Medium              Medium
# 5           19.0        88.0               Medium              Medium
# 6           29.0        84.0               Medium                 Low
# 7           25.0        78.0                  Low                High
# 8           17.0        94.0               Medium                High
# 9           23.0        98.0               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No          7.0             73.0              Low
# ...

# %%
import missingno as msno
msno.matrix(student_performance)
# Out:
# <Axes: >

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6527 non-null   float64
#  1   Attendance                  6521 non-null   float64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6526 non-null   float64
#  6   Previous_Scores             6528 non-null   float64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6523 non-null   float64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
numerical_col.fillna(numerical_col.mean(), inplace=True)
# Out:
# <ipython-input-28-52d0dc83784a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_col.fillna(numerical_col.mean(), inplace=True)

# %%
student_performance_restricted = student_performance.select_dtypes(include=['int64', 'float64'])
student_performance_restricted
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0              23.0        84.0          7.0             73.0
# 1              19.0        64.0          8.0             59.0
# 2              24.0        98.0          7.0             91.0
# 3              29.0        89.0          8.0             98.0
# 4               NaN        92.0          6.0             65.0
# ...             ...         ...          ...              ...
# 6602           25.0        69.0          7.0             76.0
# 6603           23.0        76.0          8.0             81.0
# 6604            NaN        90.0          6.0             65.0
# 6605           10.0        86.0          6.0             91.0
# 6606           15.0        67.0          9.0             94.0
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                   0.0                3.0        67.0
# 1                   2.0                4.0        61.0
# ...

# %%
student_performance.isnull().sum()
# Out:
# Hours_Studied                 80
# Attendance                    86
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                   81
# Previous_Scores               79
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions             84
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity             89
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                    82
# dtype: int64

# %%
print(student_performance.isnull().sum())
student_performance_restricted.dropna(inplace=True)
print(student_performance_restricted.isnull().sum())
# Out:
# Hours_Studied                 80
# Attendance                    86
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                   81
# Previous_Scores               79
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions             84
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity             89
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                    82
# dtype: int64
# Hours_Studied        0
# Attendance           0
# Sleep_Hours          0
# Previous_Scores      0
# Tutoring_Sessions    0
# Physical_Activity    0
# Exam_Score           0
# dtype: int64

# %%
student_performance.shape
# Out:
# (6607, 20)

# %%
student_performance_restricted.shape
# Out:
# (6046, 7)

# %%
student_performance_restricted.shape[0]
# Out:
# 6046

# %%
difference = student_performance.shape[0] - student_performance_restricted.shape[0]

# %%
difference / student_performance.shape[0] * 100
# Out:
# 8.490994399878916

# %%
student_performance_restricted.corr()
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.003900     0.012723         0.024901
# Attendance             -0.003900    1.000000    -0.018557        -0.020674
# Sleep_Hours             0.012723   -0.018557     1.000000        -0.018262
# Previous_Scores         0.024901   -0.020674    -0.018262         1.000000
# Tutoring_Sessions      -0.015869    0.013621    -0.011764        -0.009819
# Physical_Activity       0.004054   -0.023127    -0.002211        -0.003199
# Exam_Score              0.450620    0.584348    -0.015263         0.175748
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.015869           0.004054    0.450620
# Attendance                  0.013621          -0.023127    0.584348
# Sleep_Hours                -0.011764          -0.002211   -0.015263
# Previous_Scores            -0.009819          -0.003199    0.175748
# ...

# %%
plt.imshow(student_performance_restricted.corr(), clim=(-1,1), cmap='RdBu',)
plt.colorbar()
plt.xticks(range(len(student_performance_restricted.columns)), student_performance_restricted.columns, rotation=90)
plt.yticks(range(len(student_performance_restricted.columns)), student_performance_restricted.columns)
plt.show()

# %%
for c in student_performance_restricted.columns:
    plt.figure()
    plt.hist(student_performance_restricted[c])
    plt.title(c)
    plt.xlabel("Frequency")
    plt.ylabel("Exam Score")
